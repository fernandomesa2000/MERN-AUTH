# %%
#salida

output = params['A3']

# %%
if training:

    #backpropagation
    params['dZ3'] = mse(Y, putput, true) * sigmoid(params['A3'], True)
    params['dW3'] = matmul(params['A2'].T, params['dZ3'])

    params['dZ2'] = matmul(params['dZ3'].T, params['dW3']) * relu(params['A2'], True)
    params['dW3'] = matmul(params['A1'].T, params['dZ2'])

# %%
#Descenso  del gradiente

params['W3'] = params['W3'] - params['dW3'] * lr
params['b3'] = params['b3'] - (np.mean(params['dW3'], axis=0, keepdims = True)) * lr

params['W2'] = params['W2'] - params['dW2'] * lr
params['b2'] = params['b2'] - (np.mean(params['dW2'], axis=0, keepdims = True)) * lr

params['W1'] = params['W1'] - params['dW1'] * lr
params['b1'] = params['b1'] - (np.mean(params['dW1'], axis=0, keepdims = True)) * lr

return

# %%
layer_dims = [2,4,8,1]

params = initialize_parameters_deep(layer_dims)
error = []

for _ in range(5000):
    output = train(X, 0.0001, params)
    if _ % 50 == 0
        print(mse(Y,))

# %%
data_test = (np.random.rand(1000,2)*2)-1
y = train(data_test,0.001, params, training = False)

# %%
y = np.where(y >= 0.5, 1, 0)

# %%
data_test
